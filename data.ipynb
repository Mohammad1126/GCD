# %%
my_user = ['''As a Visitor,
  I want to be able to create a new account.

  Scenario: Successful account creation
    Given I am on the registration page
    When I fill in the required information
    And click the "Create Account" button
    Then I should be redirected to the login page
    And see a message indicating that my account has been created.''','''As a Visitor,
  I want to be able to login.

''','''As a Visitor,
  I want to be able to login.

  Scenario: Successful login
    Given I am on the login page
    When I enter my valid credentials
    And click the "Login" button
    Then I should be redirected to my account page
    And see a message indicating that I am logged in.
''','''As a Visitor,
  I want to be able to log out.

  Scenario: Successful logout
    Given I am logged in to my account
    When I click the "Logout" button
    Then I should be redirected to the homepage
    And see a message indicating that I have logged out.
''','''As a Visitor,
  I want to choose an event
  So that I can book a ticket for that event.

  Scenario: View Event Details
    Given I am on the events page
    When I click on an event
    Then I should be redirected to the event details page
    And see the event information including date, time, location, and ticket availability.
''','''As a Visitor,
  I want to filter events by type
  So that I can only see events of the type that I want.

  Scenario: Filter Events by Type
    Given I am on the events page
    When I select a specific event type from the filter dropdown
    Then the events displayed should only be of the selected type
    And I should see a message indicating the number of events found.
''','''As a Visitor,
  I want to be able to rename my account.

  Scenario: Rename Account
    Given I am logged in to my account
    When I navigate to the "Account Settings" page
    And enter a new name in the "Rename Account" field
    And click the "Save Changes" button
    Then my account name should be updated
    And I should see a message indicating that my account has been renamed successfully.
''','''As a Visitor,
  I want to be able to change my account password.

  Scenario: Change Account Password
    Given I am logged in to my account
    When I navigate to the "Account Settings" page
    And enter my current password and a new password in the "Change Password" fields
    And click the "Save Changes" button
    Then my account password should be updated
    And I should see a message indicating that my password has been changed successfully.
''','''As a Visitor,
  I want to search for events.

  Scenario: Search for an Event
    Given I am on the events page
    When I enter a search query in the search bar
    And click the "Search" button
    Then the events displayed should only be those that match my search query
    And I should see a message indicating the number of events found.
''','''As a Visitor,
  I want to be able to purchase multiple tickets.

  Scenario: Purchase Multiple Tickets
    Given I am logged in to my account
    And I have navigated to the event page
    When I enter the number of tickets I want to purchase in the "Number of Tickets" field
    And click the "Add to Cart" button
    Then the total cost of the tickets should be displayed
    And I should see the tickets in my cart with the correct quantity and total cost
    And I should be able to proceed to checkout and complete the purchase.
''','''As a Visitor,
  I want to see the ticket price.

  Scenario: View Ticket Price
    Given I am on the event page
    When I view the ticket section of the page
    Then the ticket prices should be displayed
    And the prices should be clear and easy to read.

''','''As a Visitor,
  I want to choose payment methods
  So that I can buy a ticket.

  Scenario: Choose Payment Method
    Given I am on the checkout page
    When I click the "Choose Payment Method" button
    Then a list of available payment methods should be displayed
    And I should be able to select my preferred payment method
    And I should see a confirmation message after selecting my preferred payment method.
''','''As a Visitor,
  I want to choose a type of ticket.

  Scenario: Choose Ticket Type
    Given I am on the event page
    When I view the ticket section of the page
    Then a list of available ticket types should be displayed
    And I should be able to select the ticket type I want to purchase
    And the ticket price should be updated based on the selected ticket type
    And the total cost of the tickets should be displayed correctly
    And I should be able to proceed to checkout and complete the purchase.
''','''As a Visitor,
  I want to provide my personal details to purchase a ticket.

  Scenario: Enter Personal Details
    Given I am on the checkout page
    When I fill out the required personal details form
    And I click the "Submit" button
    Then my personal details should be saved securely
    And I should receive a confirmation of the purchase.
''','''As a Visitor,
  I want to receive a purchased ticket.

  Scenario: Receive Purchased Ticket
    Given I have completed the purchase of a ticket
    When I navigate to the "My Tickets" section of my account
    Then the purchased ticket should be displayed
    And I should be able to download or print the ticket.
''']

# %%
len(my_user)
# Out:
# 14

# %%
my_user= ['''As an Instructor,
  I want to upload a video for a course
  So that Visitors can watch the videos.

  Scenario: Upload Course Video
    Given I am logged in as an Instructor
    When I navigate to the course management page
    And I select the course to which I want to add a video
    And I upload a video file
    Then the video should be associated with the course
    And Visitors should be able to watch the video in the course content.

''','''As an Administrator,
  I want to delete a course
  So that I can remove things that will no longer occur.

  Scenario: Delete Course
    Given I am logged in as an Administrator
    When I navigate to the course management page
    And I select the course I want to delete
    And I confirm that I want to delete it
    Then the course should be removed from the platform.
''','''As an Administrator,
  I want to delete a event
  So that I can remove things that will no longer occur.

  Scenario: Delete Event
    Given I am logged in as an Administrator
    When I navigate to the event management page
    And I select the event I want to delete
    And I confirm that I want to delete it
    Then the event should be removed from the platform.
''','''As a Site Editor,
  I want to update a course
  So that I can fix things the original author has not.

  Scenario: Update Course
    Given I am logged in as a Site Editor
    When I navigate to the course management page
    And I select the course I want to update
    And I edit the relevant fields with the updated information
    And I save the changes
    Then the course should be updated with the new information.
''','''As an instructor, 
  I can see the thumbnail image for each video
  So that the thumbnail image is one I taht like rather than randomly selected.

  Scenario: Viewing and Selecting Thumbnail Image
    Given I am logged in as an instructor
    And I am on the video management page
    When I select a video
    Then I should see the thumbnail image associated with the video
    And I have the ability to choose a different thumbnail image
    And I can save my preferred thumbnail image for the video.
''','''As an instructor,
  I can create a quiz to include in a video
  So that visitors can take those quizzes to ensure they are learning.

  Scenario: Creating a Quiz for a Video
    Given I am logged in as an instructor
    And I am on the video management page for a course
    When I select a video from the list of videos
    And I click on the "Add Quiz" button
    And I enter the quiz questions and answers
    And I click on the "Save" button
    Then the quiz should be associated with the video
    And visitors should be able to take the quiz while watching the video
    And the quiz results should be stored in the database.
''','''As an instructor,
  I can properly sequence the elements of course.

  Scenario: Sequencing Course Elements
    Given I am logged in as an instructor
    And I am on the course management page
    When I select a course from the list of courses
    And I click on the "Edit" button
    And I see a list of course elements
    And I can drag and drop elements to reorder them
    And I click on the "Save" button
    Then the course elements should be properly sequenced
    And the updated sequence should be visible to visitors of the course.
''','''As an instructor,
  I indicate whether a form is part of a course.

  Scenario: Sequencing Course Elements
    Given I am logged in as an instructor
    And I am on the course management page
    When I select a course from the list of courses
    And I click on the "Edit" button
    And I see a list of course elements
    And I can drag and drop elements to reorder them
    And I click on the "Save" button
    Then the course elements should be properly sequenced
    And the updated sequence should be visible to visitors of the course.
''','''As an instructor,
  I can see the schedule for a course so that the visitor can consult the weekly elements.

  Scenario: Displaying Course Schedule
    Given I am logged in as an instructor
    And I am on the course management page
    When I select a course from the list of courses
    And I click on the "Schedule" tab
    Then I should see a schedule of weekly elements for the course
    And visitors should be able to easily consult the weekly elements for the course.
''','''As an instructor, 
  I can add subtitles to any video
  so that it is more accessible.

  Scenario: Adding Subtitles to a Video
    Given I am logged in as an instructor
    And I am on the course management page
    When I select a video from the list of videos
    And I click on the "Subtitles" tab
    And I upload a subtitle file for the video
    Then the subtitle file should be associated with the video
    And visitors should be able to easily enable or disable subtitles for the video.
''','''As a visitor, 
  I can create an account 
  so that I can track my progress.

  Scenario: Creating an Account
    Given I am on the website's registration page
    When I fill in the required registration details
    And I click on the "Create Account" button
    Then my account should be successfully created
    And I should be logged in
    And I should be able to track my progress on the website.
''','''As an instructor, 
  I can create an event.

  Scenario: Creating an Event
    Given I am logged in as an instructor
    And I am on the event management page
    When I click on the "Create Event" button
    And I enter the necessary details for the event
    And I click on the "Save" button
    Then the event should be successfully created.
''','''As a visitor,
  I can see an event that is characterized by a name, description, start date, end date, and address.

  Scenario: Viewing Event Details
    Given I am on the website's events page
    When I select an event from the list of events
    Then I should see the event's name, description, start date, end date, and address.
''','''As an administrator, 
  I can see that the participant is a type of visitor.

  Scenario: Viewing Participant Type
    Given I am logged in as an administrator
    And I am on the participant management page
    When I select a participant from the list of participants
    Then I should see their participant type
    And I can identify if they are a visitor.
''','''As an instructor, 
  I can turn a course into an event, 
  so I can correctly classify anything that was entered incorrectly.

  Scenario: Converting a Course to an Event
    Given I am logged in as an instructor
    And I am on the course management page
    When I select a course from the list of courses
    And I click on the "Convert to Event" button
    Then the course should be successfully converted into an event
    And any incorrect classification should be corrected.
''','''As a visitor, 
  I can manage my account
  so that it reflects my current information.

  Scenario: Updating Account Information
    Given I am logged in as a visitor
    And I am on the account settings page
    When I update my account information
    And I click on the "Save" button
    Then my account should be updated with the new information
    And the changes should be reflected in my account.
''','''As a visitor, 
  I can view a list of all the courses that I have taken,
  so that I have access to that historical information and did not call someone instead.

  Scenario: Viewing Course History
    Given I am logged in as a visitor
    And I am on the account dashboard page
    When I navigate to the "Course History" section
    Then I should see a list of all the courses I have taken
    And I can access the historical information of my course participation.
''','''As an administrator, 
  I can set the listing fee for Other Course.

  Scenario: Setting Listing Fee
    Given I am logged in as an administrator
    And I am on the fee management page
    When I select the "Other Course" category
    And I set the desired listing fee
    And I click on the "Save" button
    Then the listing fee for the "Other Course" category should be updated.
''','''As an instructor, 
  I want to insert publication date of elements, 
  so that items become available when I want and not sooner.

  Scenario: Inserting Publication Date
    Given I am logged in as an instructor
    And I am on the element management page
    When I select an element
    And I enter the desired publication date
    And I click on the "Save" button
    Then the publication date for the element should be set accordingly.
''','''As an instructor, 
  I can create a quiz
  so that the participant can assess their learning.

  Scenario: Creating a Quiz
    Given I am logged in as an instructor
    And I am on the course management page
    When I select a course
    And I navigate to the quiz creation section
    And I create a new quiz with questions and answers
    And I save the quiz
    Then the quiz should be successfully created.
''','''As a participant, 
  I can take a quiz as part of a course.

  Scenario: Taking a Quiz
    Given I am logged in as a participant
    And I am enrolled in a course with a quiz
    When I navigate to the quiz section of the course
    And I start taking the quiz by answering each question
    And I submit the quiz
    Then the quiz should be marked as completed.
''','''As a participant, 
  I see if I pass a quiz after I finish taking it.

  Scenario: Viewing Quiz Result
    Given I am logged in as a participant
    And I have completed a quiz
    When I navigate to the quiz result page
    Then I should see the result of the quiz
    And I can determine if I passed or failed the quiz.
''','''As a participant, 
  I can see which quiz that I have passed, not passed, or not yet taken when viewing the course outline 
  so that I know which quiz that I need to take or possibly re-take.

  Scenario: Viewing Quiz Status in Course Outline
    Given I am logged in as a participant
    And I am enrolled in a course with multiple quizzes
    When I navigate to the course outline page
    Then I should see a list of quizzes in the course
    And for each quiz, the status should be displayed (Passed, Not Passed, Not Taken)
    And I can identify which quizzes I need to take or possibly re-take.
''','''As an instructor, 
  I want quiz responses stored in the database 
  so that I can see how people are doing at various questions, perhaps so I can fix one that is worded poorly.

  Scenario: Storing Quiz Responses
    Given I am logged in as an instructor
    And I am on the quiz management page
    When I select a quiz
    And I review the quiz responses from participants
    Then the quiz responses should be stored in the database
    And I can access the responses to analyze participant performance.
''','''As a participant, 
  I want to receive feedback after each quiz question 
  so that I can see if I got the question right or wrong.

  Scenario: Receiving Quiz Feedback
    Given I am logged in as a participant
    And I am taking a quiz
    When I answer a quiz question
    Then I should receive immediate feedback on my answer
    And I can see if my response was correct or incorrect.
''','''As a participant, 
  I can answer questions in a different order.

  Scenario: Answering Quiz Questions in Different Order
    Given I am logged in as a participant
    And I am taking a quiz
    When I answer quiz questions
    And I navigate between questions in a different order
    Then my responses should be recorded correctly
    And I can submit the quiz once I have answered all the questions.
''','''As a participant, 
  I can get an answer via video rather than text 
  so that I watch rather than read an answer.

  Scenario: Getting Video Answer
    Given I am logged in as a participant
    And I have a question
    When I request an answer
    Then the answer should be provided in video format
    And I can watch the video to get the answer.
''','''As a participant, 
  I can participate in several events.

  Scenario: Participating in Multiple Events
    Given I am logged in as a participant
    When I navigate to the events page
    And I select multiple events to participate in
    Then I should be registered for those events
    And I can access the details and join each event.
''','''As an instructor, 
  I can store responses of quiz questions.

  Scenario: Storing Quiz Responses
    Given I am logged in as an instructor
    And I have created a quiz
    When participants take the quiz and submit their responses
    Then the responses should be stored in the database
    And I can access and analyze the responses for each quiz question.
''']

# %%
len(my_user)
# Out:
# 29

# %%
my_user = ['''As a guest,
I want to be able to book a room online
So that I can easily reserve a room before my trip.
 Scenario: Book a room with available options
Given I am a guest on the hotel website
When I search for available rooms on my preferred dates
Then I should see a table of room options with prices and amenities.
''','''As a hotel staff member,
I want to be able to check room availability
So that I can inform guests whether or not we have rooms available.
Scenario: Check room availability
 Given I am a hotel staff member
When I search for available rooms on a specific date
Then I should see a table of available rooms with their types and numbers.
''','''As a hotel receptionist,
I want to be able to check in guests
So that I can register their stay and issue room keys.
 Scenario: Check in guest
Given I am a hotel receptionist
When a guest arrives at the front desk to check in
Then I should see a table of their reservation information.
''','''As a hotel receptionist,
I want to be able to check out guests
So that I can finalize their stay and process payment.
 Scenario: Check out guest
Given I am a hotel receptionist,
When a guest comes to the front desk to check out
Then I should see a table of their stay information and total cost.
''','''As a guest,
I want to be able to cancel my reservation
So that I can edit my travel plans.
Scenario: Cancel reservation
Given I am a guest with a reservation
When I go to the hotel website to cancel my reservation
Then I should see a table of my reservation information.
''','''As a guest,
I want to be able to add room service to my reservation.
 Scenario: Add room service
Given I have a confirmed room reservation
When I browse the room service menu and select items
Then the selected items should be added to my reservation and I should receive a confirmation.
''','''As a guest,
I want to be able to view the amenities of hotel.
 Scenario: View hotel amenities
Given I am a guest
When I click on "Hotel Amenities"
Then I should see a table with all available amenities and their descriptions.
''','''As a hotel staff member,
I want to be able to manage room reservations
So that I can keep track of room availability and reservations.
Scenario: Reserve a room
Given I am a hotel staff member
When I receive a request to reserve a room for a guest
Then I should reserve the requested room for the requested dates and update the room availability table.
''','''As a hotel staff member,
I want to be able to view guest reservations
So that I can provide guests with their reservations.
 Scenario: View guest reservations
Given I am a hotel staff member
When I search for reservations for a specific guest
Then I should see a table of the guest's reservations with room information and dates.
''','''As a hotel staff member,
I want to be able to manage room service orders
So that guests can order food and other items to their rooms.
 Scenario: Place a room service order
Given a guest is checked into a room
When the guest places a room service order
Then I should add the order to the room's bill and update the room service table.
''']

# %%
len(my_user)
# Out:
# 10

# %%
my_user = ['''As a student,
I want to be able to check course availability
So that I can plan my schedule accordingly.

Scenario: Check course availability
Given I am a student
When I search for a course
Then I see if the course is open for registration.
''','''As a student,
I want to be able to add myself to a waitlist for a course.

Scenario: Add myself to a waitlist
Given I am a student
And the course is full
When I add myself to the waitlist
Then I am added to the waitlist
''','''As a student,
I want to be able to drop a course
So that I can remove it from my schedule.

Scenario: Drop a course
Given I am a student
And I am enrolled in the course
When I drop the course
Then I am no longer enrolled in the course
And the course is removed from my schedule.
''','''As a student,
I want to know the deadline to enroll a course
So that I can make changes to my schedule in time.

Scenario: Check enroll deadline
Given I am a student
When I view the academic calendar
Then I see the deadline to enroll courses
And the penalty for late changes.
''','''As a student,
I want to be able to view course's grades
So that I can track my GPA.

Scenario: View my grades
Given I am a student
When I navigate to the grade report
Then I see my grades for each course
And my overall GPA.
''','''As a student,
I want to be able to track my degree progress.

Scenario: View degree audit
Given I am a student
When I navigate to the degree audit
Then I see a checklist of required courses for my major
And which ones I have completed.
''','''As a student,
I want to update my personal information.

Scenario: View and update my profile
Given I am a student
When I navigate to my profile
Then I see my personal information, such as name, address, and phone number
And I can update any outdated or incorrect information.
''','''As a student,
I want to be able to search for available courses
So that I can plan my schedule.

Scenario: Search for a course
Given I am a student
When I search for a course
Then I see a list of available courses, including their course code, title, and instructor
And I can view more information about each course, such as its description and prerequisites.
''','''As a student,
I want to be able to enroll in courses
So that I can complete my degree requirements.

Scenario: Enroll in a course
Given I am a student
When I select a course to enroll in
Then I see the course details, including the instructor and meeting times
And I can confirm my enrollment by paying the tuition or applying for financial aid.
''','''As an instructor,
I want to be characterized by a name, email, location
So that student can find me easily.

Scenario: Track attendance
Given I am an instructor
When I share my name, email and location
Then students see a list of my information.
''','''As an instructor,
I want to be able to submit course's grades.

Scenario: Submit grades
Given I am an instructor
When I enter the final grades for each student in my course
Then the grades are recorded in the university system
And the students can view their grades in their grade report.
''','''As a student,
I want to be able to apply for graduation
So that I receive my degree.

Scenario: Submit graduation application
Given I am a student who has completed all degree requirements
When I submit my graduation application
Then my application is reviewed by the university
And I am notified of my graduation status, including the date of the commencement ceremony and how to receive my diploma.
''','''As a instructor,
I want to add materials for each course.

Scenario: Access course materials
Given I am a student enrolled in a course
When I navigate to the course page
Then I can access course materials, such as lecture notes, assignments, and readings.
''','''As a student,
I want to be able to evaluate instructors.

Scenario: Evaluate a course and instructor
Given I am a student enrolled in a course
When the course is finished
Then I receive an email invitation to complete an online course evaluation.
''','''As a student,
I want to apply for scholarships.

Scenario: Apply for a scholarship
Given I am a student
When I navigate to the scholarship application page
Then I can view the list of available scholarships, eligibility requirements, and application deadlines.
''','''As an instructor,
I want to be able to create a course.

Scenario: Create a course
Given I am an instructor
When I navigate to the course creation page
Then I can provide the course name, description, syllabus, and schedule
And I can set up the course roster and grading policy.
''','''As an instructor,
I want to be able to create assignments for a course.

Scenario: Create an assignment
Given I am an instructor
When I navigate to the assignment creation page
Then I can provide the assignment name, description, due date, and point value
And I can set up the submission method and grading rubric.
''']

# %%
len(my_user)
# Out:
# 17
